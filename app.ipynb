# %%
import google.generativeai as genai

client = genai.Client(api_key="AIzaSyD4aoVne79xYBJd4eb0oZBXbPWwi3y0KHo")

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents="Once upon a time there was a"
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 import google.generativeai as genai
# ----> 3 client = genai.Client(api_key="AIzaSyD4aoVne79xYBJd4eb0oZBXbPWwi3y0KHo")
#       5 response = client.models.generate_content(
#       6     model="gemini-2.0-flash",
#       7     contents="Once upon a time there was a"
#       8 )
#      10 print(response.text)
#
# AttributeError: module 'google.generativeai' has no attribute 'Client'
